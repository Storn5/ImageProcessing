# %% [markdown]
# # Lab 3

# %%
import numpy as np
import os
import pandas as pd
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
import matplotlib.pyplot as plt
# %tensorflow_version 2.x
import tensorflow as tf
import tensorflow_datasets as tfds

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# ## Load dataset

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %%
x_train = x_train.reshape(-1, 28, 28, 1).astype('float32') / 255.
x_test = x_test.reshape(-1, 28, 28, 1).astype('float32') / 255.
y_train = y_train.astype('int')
y_test = y_test.astype('int')
print('Training', x_train.shape, x_train.max())
print('Testing', x_test.shape, x_test.max())
# Out:
# Training (60000, 28, 28, 1) 1.0
# Testing (10000, 28, 28, 1) 1.0

# %%
train_groups = [x_train[np.where(y_train==i)[0]] for i in np.unique(y_train)]
test_groups = [x_test[np.where(y_test==i)[0]] for i in np.unique(y_train)]
print('train groups:', [x.shape[0] for x in train_groups])
print('test groups:', [x.shape[0] for x in test_groups])
# Out:
# train groups: [6000, 6000, 6000, 6000, 6000, 6000, 6000, 6000, 6000, 6000]
# test groups: [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]

# %%
def gen_random_batch(in_groups, batch_halfsize = 8):
  out_img_a, out_img_b, out_score = [], [], []
  all_groups = list(range(len(in_groups)))
  for match_group in [True, False]:
    group_idx = np.random.choice(all_groups, size = batch_halfsize)
    out_img_a += [in_groups[c_idx][np.random.choice(range(in_groups[c_idx].shape[0]))] for c_idx in group_idx]
    if match_group:
      b_group_idx = group_idx
      out_score += [1]*batch_halfsize
    else:
      # anything but the same group
      non_group_idx = [np.random.choice([i for i in all_groups if i!=c_idx]) for c_idx in group_idx]
      b_group_idx = non_group_idx
      out_score += [0]*batch_halfsize

    out_img_b += [in_groups[c_idx][np.random.choice(range(in_groups[c_idx].shape[0]))] for c_idx in b_group_idx]

  return np.stack(out_img_a,0), np.stack(out_img_b,0), np.stack(out_score,0)

# %%
pv_a, pv_b, pv_sim = gen_random_batch(train_groups, 3)
fig, m_axs = plt.subplots(2, pv_a.shape[0], figsize = (12, 6))
for c_a, c_b, c_d, (ax1, ax2) in zip(pv_a, pv_b, pv_sim, m_axs.T):
  ax1.imshow(c_a[:,:,0])
  ax1.set_title('Image A')
  ax1.axis('off')
  ax2.imshow(c_b[:,:,0])
  ax2.set_title('Image B\n Similarity: %3.0f%%' % (100*c_d))
  ax2.axis('off')

# %% [markdown]
# ## DenseNet model

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization, MaxPool2D, Activation, Flatten, Dense, Dropout, SpatialDropout2D, Concatenate, AveragePooling2D
from keras.regularizers import l2
from keras.initializers import he_normal, random_normal

# %%
# Hyperparameters
num_classes = 10
l = 12
num_filter = 24
compression = 0.5
dropout_rate = 0.2
wt_decay = 0.001

# %% [markdown]
# ### Dense block
# ![image.png](https://miro.medium.com/max/948/1*GeK21UAbk4lEnNHhW_dgQA.png)
# ### Concatenation
# ![image-2.png](https://miro.medium.com/max/1200/1*9ysRPSExk0KvXR0AhNnlAA.gif)

# %%
def add_denseblock(input, num_filter = 12, dropout_rate = 0.2):
  global compression
  temp = input
  for _ in range(l):
    BatchNorm = BatchNormalization()(temp)
    relu = Activation('relu')(BatchNorm)
    Conv2D_3_3 = Conv2D(int(num_filter*compression), (3,3), use_bias=False ,padding='same', kernel_regularizer=l2(wt_decay) , kernel_initializer=(random_normal(stddev=np.sqrt(2.0/(9*int(num_filter))))))(relu)
    Conv2D_3_3 = SpatialDropout2D(dropout_rate)(Conv2D_3_3)
    concat = Concatenate(axis=-1)([temp,Conv2D_3_3])

    temp = concat

  return temp

# %%
def add_transition(input, num_filter = 12, dropout_rate = 0.2):
  global compression
  BatchNorm = BatchNormalization()(input)
  relu = Activation('relu')(BatchNorm)
  Conv2D_BottleNeck = Conv2D(int(int(input.shape[-1])*compression), (1,1), use_bias=False ,padding='same',kernel_regularizer=l2(wt_decay) , kernel_initializer=(random_normal(stddev=np.sqrt(2.0/(9*int(num_filter*compression))))))(relu)
  Conv2D_BottleNeck = SpatialDropout2D(dropout_rate)(Conv2D_BottleNeck)
  avg = AveragePooling2D(pool_size=(2,2))(Conv2D_BottleNeck)

  return avg

# %%
def output_layer(input):
  global compression
  BatchNorm = BatchNormalization()(input)
  relu = Activation('relu')(BatchNorm)
  AvgPooling = AveragePooling2D(pool_size=(2,2))(relu)
  flat = Flatten()(AvgPooling)
  output = Dense(num_classes, activation='softmax', kernel_regularizer=l2(wt_decay))(flat)

  return output

# %% [markdown]
# ### Overall DenseNet structure
# ![image.png](https://miro.medium.com/max/1400/1*BJM5Ht9D5HcP5CFpu8bn7g.png)

# %%
img_in = Input(shape = x_train.shape[1:], name = 'FeatureNet_ImageInput')
First_Conv2D = Conv2D(int(num_filter), (3,3), use_bias=False , padding='same', kernel_regularizer=l2(wt_decay), kernel_initializer=(random_normal(stddev=np.sqrt(2.0/(9*num_filter)))))(img_in)

First_Block = add_denseblock(First_Conv2D, num_filter, dropout_rate)
First_Transition = add_transition(First_Block, num_filter, dropout_rate)

Second_Block = add_denseblock(First_Transition, num_filter, dropout_rate)
Second_Transition = add_transition(Second_Block, num_filter, dropout_rate)

Third_Block = add_denseblock(Second_Transition, num_filter, dropout_rate)
Third_Transition = add_transition(Third_Block, num_filter, dropout_rate)

Last_Block = add_denseblock(Third_Transition,  num_filter, dropout_rate)
Last_Block = output_layer(Last_Block)

feature_model = Model(inputs = [img_in], outputs = [Last_Block], name = 'FeatureGenerationModel')
feature_model.summary()
# Out:
# Model: "FeatureGenerationModel"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  FeatureNet_ImageInput (InputLa  [(None, 28, 28, 1)]  0          []
#  yer)
#
#  conv2d_1 (Conv2D)              (None, 28, 28, 24)   216         ['FeatureNet_ImageInput[0][0]']
#
#  batch_normalization (BatchNorm  (None, 28, 28, 24)  96          ['conv2d_1[0][0]']
#  alization)
#
#  activation (Activation)        (None, 28, 28, 24)   0           ['batch_normalization[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 28, 28, 12)   2592        ['activation[0][0]']
#
#  spatial_dropout2d (SpatialDrop  (None, 28, 28, 12)  0           ['conv2d_2[0][0]']
#  out2D)
#
#  concatenate (Concatenate)      (None, 28, 28, 36)   0           ['conv2d_1[0][0]',
#                                                                   'spatial_dropout2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 28, 28, 36)  144         ['concatenate[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 28, 28, 36)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 12)   3888        ['activation_1[0][0]']
#
#  spatial_dropout2d_1 (SpatialDr  (None, 28, 28, 12)  0           ['conv2d_3[0][0]']
#  opout2D)
#
#  concatenate_1 (Concatenate)    (None, 28, 28, 48)   0           ['concatenate[0][0]',
#                                                                   'spatial_dropout2d_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 28, 28, 48)  192         ['concatenate_1[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 28, 28, 48)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 12)   5184        ['activation_2[0][0]']
#
#  spatial_dropout2d_2 (SpatialDr  (None, 28, 28, 12)  0           ['conv2d_4[0][0]']
#  opout2D)
#
#  concatenate_2 (Concatenate)    (None, 28, 28, 60)   0           ['concatenate_1[0][0]',
#                                                                   'spatial_dropout2d_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 28, 28, 60)  240         ['concatenate_2[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 28, 28, 60)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 28, 28, 12)   6480        ['activation_3[0][0]']
#
#  spatial_dropout2d_3 (SpatialDr  (None, 28, 28, 12)  0           ['conv2d_5[0][0]']
#  opout2D)
#
#  concatenate_3 (Concatenate)    (None, 28, 28, 72)   0           ['concatenate_2[0][0]',
#                                                                   'spatial_dropout2d_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 28, 28, 72)  288         ['concatenate_3[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 28, 28, 72)   0           ['batch_normalization_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 12)   7776        ['activation_4[0][0]']
#
#  spatial_dropout2d_4 (SpatialDr  (None, 28, 28, 12)  0           ['conv2d_6[0][0]']
#  opout2D)
#
#  concatenate_4 (Concatenate)    (None, 28, 28, 84)   0           ['concatenate_3[0][0]',
#                                                                   'spatial_dropout2d_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 28, 28, 84)  336         ['concatenate_4[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 28, 28, 84)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 12)   9072        ['activation_5[0][0]']
#
#  spatial_dropout2d_5 (SpatialDr  (None, 28, 28, 12)  0           ['conv2d_7[0][0]']
#  opout2D)
#
#  concatenate_5 (Concatenate)    (None, 28, 28, 96)   0           ['concatenate_4[0][0]',
#                                                                   'spatial_dropout2d_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 28, 28, 96)  384         ['concatenate_5[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 28, 28, 96)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 28, 28, 12)   10368       ['activation_6[0][0]']
#
#  spatial_dropout2d_6 (SpatialDr  (None, 28, 28, 12)  0           ['conv2d_8[0][0]']
#  opout2D)
#
#  concatenate_6 (Concatenate)    (None, 28, 28, 108)  0           ['concatenate_5[0][0]',
#                                                                   'spatial_dropout2d_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 28, 28, 108)  432        ['concatenate_6[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 28, 28, 108)  0           ['batch_normalization_7[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 12)   11664       ['activation_7[0][0]']
#
#  spatial_dropout2d_7 (SpatialDr  (None, 28, 28, 12)  0           ['conv2d_9[0][0]']
#  opout2D)
#
#  concatenate_7 (Concatenate)    (None, 28, 28, 120)  0           ['concatenate_6[0][0]',
#                                                                   'spatial_dropout2d_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 28, 28, 120)  480        ['concatenate_7[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 28, 28, 120)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 12)   12960       ['activation_8[0][0]']
#
#  spatial_dropout2d_8 (SpatialDr  (None, 28, 28, 12)  0           ['conv2d_10[0][0]']
#  opout2D)
#
#  concatenate_8 (Concatenate)    (None, 28, 28, 132)  0           ['concatenate_7[0][0]',
#                                                                   'spatial_dropout2d_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 28, 28, 132)  528        ['concatenate_8[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 28, 28, 132)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 12)   14256       ['activation_9[0][0]']
#
#  spatial_dropout2d_9 (SpatialDr  (None, 28, 28, 12)  0           ['conv2d_11[0][0]']
#  opout2D)
#
#  concatenate_9 (Concatenate)    (None, 28, 28, 144)  0           ['concatenate_8[0][0]',
#                                                                   'spatial_dropout2d_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 28, 28, 144)  576        ['concatenate_9[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 28, 28, 144)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 12)   15552       ['activation_10[0][0]']
#
#  spatial_dropout2d_10 (SpatialD  (None, 28, 28, 12)  0           ['conv2d_12[0][0]']
#  ropout2D)
#
#  concatenate_10 (Concatenate)   (None, 28, 28, 156)  0           ['concatenate_9[0][0]',
#                                                                   'spatial_dropout2d_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 28, 28, 156)  624        ['concatenate_10[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 28, 28, 156)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 12)   16848       ['activation_11[0][0]']
#
#  spatial_dropout2d_11 (SpatialD  (None, 28, 28, 12)  0           ['conv2d_13[0][0]']
#  ropout2D)
#
#  concatenate_11 (Concatenate)   (None, 28, 28, 168)  0           ['concatenate_10[0][0]',
#                                                                   'spatial_dropout2d_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 28, 28, 168)  672        ['concatenate_11[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 28, 28, 168)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 84)   14112       ['activation_12[0][0]']
#
#  spatial_dropout2d_12 (SpatialD  (None, 28, 28, 84)  0           ['conv2d_14[0][0]']
#  ropout2D)
#
#  average_pooling2d (AveragePool  (None, 14, 14, 84)  0           ['spatial_dropout2d_12[0][0]']
#  ing2D)
#
#  batch_normalization_13 (BatchN  (None, 14, 14, 84)  336         ['average_pooling2d[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 14, 14, 84)   0           ['batch_normalization_13[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 14, 14, 12)   9072        ['activation_13[0][0]']
#
#  spatial_dropout2d_13 (SpatialD  (None, 14, 14, 12)  0           ['conv2d_15[0][0]']
#  ropout2D)
#
#  concatenate_12 (Concatenate)   (None, 14, 14, 96)   0           ['average_pooling2d[0][0]',
#                                                                   'spatial_dropout2d_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 14, 14, 96)  384         ['concatenate_12[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 14, 14, 96)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 14, 14, 12)   10368       ['activation_14[0][0]']
#
#  spatial_dropout2d_14 (SpatialD  (None, 14, 14, 12)  0           ['conv2d_16[0][0]']
#  ropout2D)
#
#  concatenate_13 (Concatenate)   (None, 14, 14, 108)  0           ['concatenate_12[0][0]',
#                                                                   'spatial_dropout2d_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 14, 14, 108)  432        ['concatenate_13[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 14, 14, 108)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 14, 14, 12)   11664       ['activation_15[0][0]']
#
#  spatial_dropout2d_15 (SpatialD  (None, 14, 14, 12)  0           ['conv2d_17[0][0]']
#  ropout2D)
#
#  concatenate_14 (Concatenate)   (None, 14, 14, 120)  0           ['concatenate_13[0][0]',
#                                                                   'spatial_dropout2d_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 14, 14, 120)  480        ['concatenate_14[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 14, 14, 120)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 14, 14, 12)   12960       ['activation_16[0][0]']
#
#  spatial_dropout2d_16 (SpatialD  (None, 14, 14, 12)  0           ['conv2d_18[0][0]']
#  ropout2D)
#
#  concatenate_15 (Concatenate)   (None, 14, 14, 132)  0           ['concatenate_14[0][0]',
#                                                                   'spatial_dropout2d_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 14, 14, 132)  528        ['concatenate_15[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 14, 14, 132)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 14, 14, 12)   14256       ['activation_17[0][0]']
#
#  spatial_dropout2d_17 (SpatialD  (None, 14, 14, 12)  0           ['conv2d_19[0][0]']
#  ropout2D)
#
#  concatenate_16 (Concatenate)   (None, 14, 14, 144)  0           ['concatenate_15[0][0]',
#                                                                   'spatial_dropout2d_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 14, 14, 144)  576        ['concatenate_16[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 14, 14, 144)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 14, 14, 12)   15552       ['activation_18[0][0]']
#
#  spatial_dropout2d_18 (SpatialD  (None, 14, 14, 12)  0           ['conv2d_20[0][0]']
#  ropout2D)
#
#  concatenate_17 (Concatenate)   (None, 14, 14, 156)  0           ['concatenate_16[0][0]',
#                                                                   'spatial_dropout2d_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 14, 14, 156)  624        ['concatenate_17[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 14, 14, 156)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 14, 14, 12)   16848       ['activation_19[0][0]']
#
#  spatial_dropout2d_19 (SpatialD  (None, 14, 14, 12)  0           ['conv2d_21[0][0]']
#  ropout2D)
#
#  concatenate_18 (Concatenate)   (None, 14, 14, 168)  0           ['concatenate_17[0][0]',
#                                                                   'spatial_dropout2d_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 14, 14, 168)  672        ['concatenate_18[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 14, 14, 168)  0           ['batch_normalization_20[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 14, 14, 12)   18144       ['activation_20[0][0]']
#
#  spatial_dropout2d_20 (SpatialD  (None, 14, 14, 12)  0           ['conv2d_22[0][0]']
#  ropout2D)
#
#  concatenate_19 (Concatenate)   (None, 14, 14, 180)  0           ['concatenate_18[0][0]',
#                                                                   'spatial_dropout2d_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 14, 14, 180)  720        ['concatenate_19[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 14, 14, 180)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 14, 14, 12)   19440       ['activation_21[0][0]']
#
#  spatial_dropout2d_21 (SpatialD  (None, 14, 14, 12)  0           ['conv2d_23[0][0]']
#  ropout2D)
#
#  concatenate_20 (Concatenate)   (None, 14, 14, 192)  0           ['concatenate_19[0][0]',
#                                                                   'spatial_dropout2d_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 14, 14, 192)  768        ['concatenate_20[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_22[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 14, 14, 12)   20736       ['activation_22[0][0]']
#
#  spatial_dropout2d_22 (SpatialD  (None, 14, 14, 12)  0           ['conv2d_24[0][0]']
#  ropout2D)
#
#  concatenate_21 (Concatenate)   (None, 14, 14, 204)  0           ['concatenate_20[0][0]',
#                                                                   'spatial_dropout2d_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 14, 14, 204)  816        ['concatenate_21[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 14, 14, 204)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 14, 14, 12)   22032       ['activation_23[0][0]']
#
#  spatial_dropout2d_23 (SpatialD  (None, 14, 14, 12)  0           ['conv2d_25[0][0]']
#  ropout2D)
#
#  concatenate_22 (Concatenate)   (None, 14, 14, 216)  0           ['concatenate_21[0][0]',
#                                                                   'spatial_dropout2d_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 14, 14, 216)  864        ['concatenate_22[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 14, 14, 216)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 14, 14, 12)   23328       ['activation_24[0][0]']
#
#  spatial_dropout2d_24 (SpatialD  (None, 14, 14, 12)  0           ['conv2d_26[0][0]']
#  ropout2D)
#
#  concatenate_23 (Concatenate)   (None, 14, 14, 228)  0           ['concatenate_22[0][0]',
#                                                                   'spatial_dropout2d_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 14, 14, 228)  912        ['concatenate_23[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 14, 14, 228)  0           ['batch_normalization_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 14, 14, 114)  25992       ['activation_25[0][0]']
#
#  spatial_dropout2d_25 (SpatialD  (None, 14, 14, 114)  0          ['conv2d_27[0][0]']
#  ropout2D)
#
#  average_pooling2d_1 (AveragePo  (None, 7, 7, 114)   0           ['spatial_dropout2d_25[0][0]']
#  oling2D)
#
#  batch_normalization_26 (BatchN  (None, 7, 7, 114)   456         ['average_pooling2d_1[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 7, 7, 114)    0           ['batch_normalization_26[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 7, 7, 12)     12312       ['activation_26[0][0]']
#
#  spatial_dropout2d_26 (SpatialD  (None, 7, 7, 12)    0           ['conv2d_28[0][0]']
#  ropout2D)
#
#  concatenate_24 (Concatenate)   (None, 7, 7, 126)    0           ['average_pooling2d_1[0][0]',
#                                                                   'spatial_dropout2d_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 7, 7, 126)   504         ['concatenate_24[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 7, 7, 126)    0           ['batch_normalization_27[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 7, 7, 12)     13608       ['activation_27[0][0]']
#
#  spatial_dropout2d_27 (SpatialD  (None, 7, 7, 12)    0           ['conv2d_29[0][0]']
#  ropout2D)
#
#  concatenate_25 (Concatenate)   (None, 7, 7, 138)    0           ['concatenate_24[0][0]',
#                                                                   'spatial_dropout2d_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 7, 7, 138)   552         ['concatenate_25[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 7, 7, 138)    0           ['batch_normalization_28[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 7, 7, 12)     14904       ['activation_28[0][0]']
#
#  spatial_dropout2d_28 (SpatialD  (None, 7, 7, 12)    0           ['conv2d_30[0][0]']
#  ropout2D)
#
#  concatenate_26 (Concatenate)   (None, 7, 7, 150)    0           ['concatenate_25[0][0]',
#                                                                   'spatial_dropout2d_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 7, 7, 150)   600         ['concatenate_26[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 7, 7, 150)    0           ['batch_normalization_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 7, 7, 12)     16200       ['activation_29[0][0]']
#
#  spatial_dropout2d_29 (SpatialD  (None, 7, 7, 12)    0           ['conv2d_31[0][0]']
#  ropout2D)
#
#  concatenate_27 (Concatenate)   (None, 7, 7, 162)    0           ['concatenate_26[0][0]',
#                                                                   'spatial_dropout2d_29[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 7, 7, 162)   648         ['concatenate_27[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 7, 7, 162)    0           ['batch_normalization_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 7, 7, 12)     17496       ['activation_30[0][0]']
#
#  spatial_dropout2d_30 (SpatialD  (None, 7, 7, 12)    0           ['conv2d_32[0][0]']
#  ropout2D)
#
#  concatenate_28 (Concatenate)   (None, 7, 7, 174)    0           ['concatenate_27[0][0]',
#                                                                   'spatial_dropout2d_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 7, 7, 174)   696         ['concatenate_28[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 7, 7, 174)    0           ['batch_normalization_31[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 7, 7, 12)     18792       ['activation_31[0][0]']
#
#  spatial_dropout2d_31 (SpatialD  (None, 7, 7, 12)    0           ['conv2d_33[0][0]']
#  ropout2D)
#
#  concatenate_29 (Concatenate)   (None, 7, 7, 186)    0           ['concatenate_28[0][0]',
#                                                                   'spatial_dropout2d_31[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 7, 7, 186)   744         ['concatenate_29[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 7, 7, 186)    0           ['batch_normalization_32[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 7, 7, 12)     20088       ['activation_32[0][0]']
#
#  spatial_dropout2d_32 (SpatialD  (None, 7, 7, 12)    0           ['conv2d_34[0][0]']
#  ropout2D)
#
#  concatenate_30 (Concatenate)   (None, 7, 7, 198)    0           ['concatenate_29[0][0]',
#                                                                   'spatial_dropout2d_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 7, 7, 198)   792         ['concatenate_30[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 7, 7, 198)    0           ['batch_normalization_33[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 7, 7, 12)     21384       ['activation_33[0][0]']
#
#  spatial_dropout2d_33 (SpatialD  (None, 7, 7, 12)    0           ['conv2d_35[0][0]']
#  ropout2D)
#
#  concatenate_31 (Concatenate)   (None, 7, 7, 210)    0           ['concatenate_30[0][0]',
#                                                                   'spatial_dropout2d_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 7, 7, 210)   840         ['concatenate_31[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 7, 7, 210)    0           ['batch_normalization_34[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 7, 7, 12)     22680       ['activation_34[0][0]']
#
#  spatial_dropout2d_34 (SpatialD  (None, 7, 7, 12)    0           ['conv2d_36[0][0]']
#  ropout2D)
#
#  concatenate_32 (Concatenate)   (None, 7, 7, 222)    0           ['concatenate_31[0][0]',
#                                                                   'spatial_dropout2d_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 7, 7, 222)   888         ['concatenate_32[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 7, 7, 222)    0           ['batch_normalization_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 7, 7, 12)     23976       ['activation_35[0][0]']
#
#  spatial_dropout2d_35 (SpatialD  (None, 7, 7, 12)    0           ['conv2d_37[0][0]']
#  ropout2D)
#
#  concatenate_33 (Concatenate)   (None, 7, 7, 234)    0           ['concatenate_32[0][0]',
#                                                                   'spatial_dropout2d_35[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 7, 7, 234)   936         ['concatenate_33[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 7, 7, 234)    0           ['batch_normalization_36[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 7, 7, 12)     25272       ['activation_36[0][0]']
#
#  spatial_dropout2d_36 (SpatialD  (None, 7, 7, 12)    0           ['conv2d_38[0][0]']
# ...
#  concatenate_36 (Concatenate)   (None, 3, 3, 141)    0           ['average_pooling2d_2[0][0]',
#                                                                   'spatial_dropout2d_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 3, 3, 141)   564         ['concatenate_36[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 3, 3, 141)    0           ['batch_normalization_40[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 3, 3, 12)     15228       ['activation_40[0][0]']
#
#  spatial_dropout2d_40 (SpatialD  (None, 3, 3, 12)    0           ['conv2d_42[0][0]']
#  ropout2D)
#
#  concatenate_37 (Concatenate)   (None, 3, 3, 153)    0           ['concatenate_36[0][0]',
#                                                                   'spatial_dropout2d_40[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 3, 3, 153)   612         ['concatenate_37[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 3, 3, 153)    0           ['batch_normalization_41[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 3, 3, 12)     16524       ['activation_41[0][0]']
#
#  spatial_dropout2d_41 (SpatialD  (None, 3, 3, 12)    0           ['conv2d_43[0][0]']
#  ropout2D)
#
#  concatenate_38 (Concatenate)   (None, 3, 3, 165)    0           ['concatenate_37[0][0]',
#                                                                   'spatial_dropout2d_41[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 3, 3, 165)   660         ['concatenate_38[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 3, 3, 165)    0           ['batch_normalization_42[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 3, 3, 12)     17820       ['activation_42[0][0]']
#
#  spatial_dropout2d_42 (SpatialD  (None, 3, 3, 12)    0           ['conv2d_44[0][0]']
#  ropout2D)
#
#  concatenate_39 (Concatenate)   (None, 3, 3, 177)    0           ['concatenate_38[0][0]',
#                                                                   'spatial_dropout2d_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 3, 3, 177)   708         ['concatenate_39[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 3, 3, 177)    0           ['batch_normalization_43[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 3, 3, 12)     19116       ['activation_43[0][0]']
#
#  spatial_dropout2d_43 (SpatialD  (None, 3, 3, 12)    0           ['conv2d_45[0][0]']
#  ropout2D)
#
#  concatenate_40 (Concatenate)   (None, 3, 3, 189)    0           ['concatenate_39[0][0]',
#                                                                   'spatial_dropout2d_43[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 3, 3, 189)   756         ['concatenate_40[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 3, 3, 189)    0           ['batch_normalization_44[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 3, 3, 12)     20412       ['activation_44[0][0]']
#
#  spatial_dropout2d_44 (SpatialD  (None, 3, 3, 12)    0           ['conv2d_46[0][0]']
#  ropout2D)
#
#  concatenate_41 (Concatenate)   (None, 3, 3, 201)    0           ['concatenate_40[0][0]',
#                                                                   'spatial_dropout2d_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 3, 3, 201)   804         ['concatenate_41[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 3, 3, 201)    0           ['batch_normalization_45[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 3, 3, 12)     21708       ['activation_45[0][0]']
#
#  spatial_dropout2d_45 (SpatialD  (None, 3, 3, 12)    0           ['conv2d_47[0][0]']
#  ropout2D)
#
#  concatenate_42 (Concatenate)   (None, 3, 3, 213)    0           ['concatenate_41[0][0]',
#                                                                   'spatial_dropout2d_45[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 3, 3, 213)   852         ['concatenate_42[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 3, 3, 213)    0           ['batch_normalization_46[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 3, 3, 12)     23004       ['activation_46[0][0]']
#
#  spatial_dropout2d_46 (SpatialD  (None, 3, 3, 12)    0           ['conv2d_48[0][0]']
#  ropout2D)
#
#  concatenate_43 (Concatenate)   (None, 3, 3, 225)    0           ['concatenate_42[0][0]',
#                                                                   'spatial_dropout2d_46[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 3, 3, 225)   900         ['concatenate_43[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 3, 3, 225)    0           ['batch_normalization_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 3, 3, 12)     24300       ['activation_47[0][0]']
#
#  spatial_dropout2d_47 (SpatialD  (None, 3, 3, 12)    0           ['conv2d_49[0][0]']
#  ropout2D)
#
#  concatenate_44 (Concatenate)   (None, 3, 3, 237)    0           ['concatenate_43[0][0]',
#                                                                   'spatial_dropout2d_47[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 3, 3, 237)   948         ['concatenate_44[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 3, 3, 237)    0           ['batch_normalization_48[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 3, 3, 12)     25596       ['activation_48[0][0]']
#
#  spatial_dropout2d_48 (SpatialD  (None, 3, 3, 12)    0           ['conv2d_50[0][0]']
#  ropout2D)
#
#  concatenate_45 (Concatenate)   (None, 3, 3, 249)    0           ['concatenate_44[0][0]',
#                                                                   'spatial_dropout2d_48[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 3, 3, 249)   996         ['concatenate_45[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 3, 3, 249)    0           ['batch_normalization_49[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 3, 3, 12)     26892       ['activation_49[0][0]']
#
#  spatial_dropout2d_49 (SpatialD  (None, 3, 3, 12)    0           ['conv2d_51[0][0]']
#  ropout2D)
#
#  concatenate_46 (Concatenate)   (None, 3, 3, 261)    0           ['concatenate_45[0][0]',
#                                                                   'spatial_dropout2d_49[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 3, 3, 261)   1044        ['concatenate_46[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 3, 3, 261)    0           ['batch_normalization_50[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 3, 3, 12)     28188       ['activation_50[0][0]']
#
#  spatial_dropout2d_50 (SpatialD  (None, 3, 3, 12)    0           ['conv2d_52[0][0]']
#  ropout2D)
#
#  concatenate_47 (Concatenate)   (None, 3, 3, 273)    0           ['concatenate_46[0][0]',
#                                                                   'spatial_dropout2d_50[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 3, 3, 273)   1092        ['concatenate_47[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 3, 3, 273)    0           ['batch_normalization_51[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 1, 1, 273)   0           ['activation_51[0][0]']
#  oling2D)
#
#  flatten (Flatten)              (None, 273)          0           ['average_pooling2d_3[0][0]']
#
#  dense (Dense)                  (None, 10)           2740        ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 906,610
# Trainable params: 889,996
# Non-trainable params: 16,614
# __________________________________________________________________________________________________

# %% [markdown]
# ## Siamese networks
# ![image.png](https://miro.medium.com/max/1400/1*0E9104t29iMBmtvq7G1G6Q.png)

# %%
from keras.layers import concatenate
img_a_in = Input(shape = x_train.shape[1:], name = 'ImageA_Input')
img_b_in = Input(shape = x_train.shape[1:], name = 'ImageB_Input')
img_a_feat = feature_model(img_a_in)
img_b_feat = feature_model(img_b_in)
combined_features = concatenate([img_a_feat, img_b_feat], name = 'merge_features')
combined_features = Dense(16, activation = 'linear')(combined_features)
combined_features = BatchNormalization()(combined_features)
combined_features = Activation('relu')(combined_features)
combined_features = Dense(4, activation = 'linear')(combined_features)
combined_features = BatchNormalization()(combined_features)
combined_features = Activation('relu')(combined_features)
combined_features = Dense(1, activation = 'sigmoid')(combined_features)
similarity_model = Model(inputs = [img_a_in, img_b_in], outputs = [combined_features], name = 'Similarity_Model')
similarity_model.summary()
# Out:
# Model: "Similarity_Model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  ImageA_Input (InputLayer)      [(None, 28, 28, 1)]  0           []
#
#  ImageB_Input (InputLayer)      [(None, 28, 28, 1)]  0           []
#
#  FeatureGenerationModel (Functi  (None, 10)          906610      ['ImageA_Input[0][0]',
#  onal)                                                            'ImageB_Input[0][0]']
#
#  merge_features (Concatenate)   (None, 20)           0           ['FeatureGenerationModel[0][0]',
#                                                                   'FeatureGenerationModel[1][0]']
#
#  dense_1 (Dense)                (None, 16)           336         ['merge_features[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 16)          64          ['dense_1[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 16)           0           ['batch_normalization_52[0][0]']
#
#  dense_2 (Dense)                (None, 4)            68          ['activation_52[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 4)           16          ['dense_2[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 4)            0           ['batch_normalization_53[0][0]']
#
#  dense_3 (Dense)                (None, 1)            5           ['activation_53[0][0]']
#
# ==================================================================================================
# Total params: 907,099
# Trainable params: 890,445
# Non-trainable params: 16,654
# __________________________________________________________________________________________________

# %% [markdown]
# ## Before training

# %%
# setup the optimization process
similarity_model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['mae'])

# %%
def show_model_output(nb_examples = 3):
  pv_a, pv_b, pv_sim = gen_random_batch(test_groups, nb_examples)
  pred_sim = similarity_model.predict([pv_a, pv_b])
  fig, m_axs = plt.subplots(2, pv_a.shape[0], figsize = (12, 6))
  for c_a, c_b, c_d, p_d, (ax1, ax2) in zip(pv_a, pv_b, pv_sim, pred_sim, m_axs.T):
    ax1.imshow(c_a[:,:,0])
    ax1.set_title('Image A\n Actual: %3.0f%%' % (100*c_d))
    ax1.axis('off')
    ax2.imshow(c_b[:,:,0])
    ax2.set_title('Image B\n Predicted: %3.0f%%' % (100*p_d))
    ax2.axis('off')
  return fig
# a completely untrained model
_ = show_model_output()

# %% [markdown]
# ## Training

# %%
# make a generator out of the data
def siam_gen(in_groups, batch_size = 32):
  while True:
    pv_a, pv_b, pv_sim = gen_random_batch(train_groups, batch_size//2)
    yield [pv_a, pv_b], pv_sim
# we want a constant validation group to have a frame of reference for model performance
valid_a, valid_b, valid_sim = gen_random_batch(test_groups, 1024)
loss_history = similarity_model.fit_generator(siam_gen(train_groups), steps_per_epoch = 500, validation_data=([valid_a, valid_b], valid_sim), epochs = 10, verbose = True)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# 500/500 [==============================] - 158s 270ms/step - loss: 4.4408 - mae: 0.5003 - val_loss: 1.6825 - val_mae: 0.5000
# Epoch 2/10
# 500/500 [==============================] - 132s 264ms/step - loss: 1.1186 - mae: 0.4994 - val_loss: 0.8360 - val_mae: 0.4949
# Epoch 3/10
# 500/500 [==============================] - 131s 263ms/step - loss: 0.6797 - mae: 0.3908 - val_loss: 0.5774 - val_mae: 0.3077
# Epoch 4/10
# 500/500 [==============================] - 131s 262ms/step - loss: 0.5654 - mae: 0.3029 - val_loss: 0.5234 - val_mae: 0.2826
# Epoch 5/10
# 500/500 [==============================] - 131s 263ms/step - loss: 0.5154 - mae: 0.2720 - val_loss: 0.4811 - val_mae: 0.2496
# Epoch 6/10
# 500/500 [==============================] - 131s 262ms/step - loss: 0.5042 - mae: 0.2552 - val_loss: 0.4820 - val_mae: 0.2496
# Epoch 7/10
# 500/500 [==============================] - 131s 262ms/step - loss: 0.4951 - mae: 0.2528 - val_loss: 0.4688 - val_mae: 0.2283
# Epoch 8/10
# 500/500 [==============================] - 131s 263ms/step - loss: 0.4791 - mae: 0.2431 - val_loss: 0.4672 - val_mae: 0.2323
# Epoch 9/10
# 500/500 [==============================] - 131s 261ms/step - loss: 0.4911 - mae: 0.2449 - val_loss: 0.4753 - val_mae: 0.2352
# Epoch 10/10
# 500/500 [==============================] - 130s 261ms/step - loss: 0.4822 - mae: 0.2413 - val_loss: 0.4454 - val_mae: 0.2198

# %%
_ = show_model_output()

# %% [markdown]
# ## Feature visualization

# %%
t_shirt_vec = np.stack([train_groups[0][0]]*x_test.shape[0],0)
t_shirt_score = similarity_model.predict([t_shirt_vec, x_test], verbose = True, batch_size = 128)
ankle_boot_vec = np.stack([train_groups[-1][0]]*x_test.shape[0],0)
ankle_boot_score = similarity_model.predict([ankle_boot_vec, x_test], verbose = True, batch_size = 128)
# Out:
# 79/79 [==============================] - 17s 183ms/step
# 79/79 [==============================] - 14s 178ms/step

# %%
obj_categories = ['T-shirt/top','Trouser','Pullover','Dress', 'Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']
colors = plt.cm.rainbow(np.linspace(0, 1, 10))
plt.figure(figsize=(10, 10))
for c_group, (c_color, c_label) in enumerate(zip(colors, obj_categories)):
  plt.scatter(t_shirt_score[np.where(y_test == c_group), 0], ankle_boot_score[np.where(y_test == c_group), 0], marker='.', color=c_color, linewidth='1', alpha=0.8, label=c_label)
plt.xlabel('T-Shirt Dimension')
plt.ylabel('Ankle-Boot Dimension')
plt.title('T-Shirt and Ankle-Boot Dimension')
plt.legend(loc='best')
plt.savefig('tshirt-boot-dist.png')
plt.show(block=False)

# %% [markdown]
# ## TSNE visualization

# %%
x_test_features = feature_model.predict(x_test, verbose = True, batch_size=128)
# Out:
# 79/79 [==============================] - 8s 88ms/step

# %%
# %%time
from sklearn.manifold import TSNE
tsne_obj = TSNE(n_components=2, init='pca', random_state=101, method='barnes_hut', n_iter=500, verbose=2)
tsne_features = tsne_obj.fit_transform(x_test_features)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.017s...
# [t-SNE] Computed neighbors for 10000 samples in 0.546s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 0.001767
# [t-SNE] Computed conditional probabilities in 1.927s
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,
# [t-SNE] Iteration 50: error = 75.9956207, gradient norm = 0.0084477 (50 iterations in 3.773s)
# [t-SNE] Iteration 100: error = 70.2835999, gradient norm = 0.0037051 (50 iterations in 8.498s)
# [t-SNE] Iteration 150: error = 67.6103210, gradient norm = 0.0025605 (50 iterations in 4.765s)
# [t-SNE] Iteration 200: error = 66.0450745, gradient norm = 0.0019060 (50 iterations in 3.697s)
# [t-SNE] Iteration 250: error = 65.0197449, gradient norm = 0.0015173 (50 iterations in 3.703s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 65.019745
# [t-SNE] Iteration 300: error = 2.1658287, gradient norm = 0.0012879 (50 iterations in 3.669s)
# [t-SNE] Iteration 350: error = 1.5877873, gradient norm = 0.0006406 (50 iterations in 3.602s)
# [t-SNE] Iteration 400: error = 1.2789114, gradient norm = 0.0003860 (50 iterations in 3.619s)
# [t-SNE] Iteration 450: error = 1.0988524, gradient norm = 0.0002626 (50 iterations in 3.643s)
# [t-SNE] Iteration 500: error = 0.9832500, gradient norm = 0.0001927 (50 iterations in 3.595s)
# [t-SNE] KL divergence after 500 iterations: 0.983250
# CPU times: user 1min 10s, sys: 531 ms, total: 1min 10s
# Wall time: 45.3 s

# %%
obj_categories = ['T-shirt/top','Trouser','Pullover','Dress', 'Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']
colors = plt.cm.rainbow(np.linspace(0, 1, 10))
plt.figure(figsize=(10, 10))
for c_group, (c_color, c_label) in enumerate(zip(colors, obj_categories)):
  plt.scatter(tsne_features[np.where(y_test == c_group), 0], tsne_features[np.where(y_test == c_group), 1], marker='o', color=c_color, linewidth='1', alpha=0.8, label=c_label)
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('t-SNE on Testing Samples')
plt.legend(loc='best')
plt.savefig('clothes-dist.png')
plt.show(block=False)
